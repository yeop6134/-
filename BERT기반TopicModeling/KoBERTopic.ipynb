# %% [markdown]
# <a href="https://colab.research.google.com/github/yeop6134/Ai_humanities/blob/main/BERT%EA%B8%B0%EB%B0%98TopicModeling/KoBERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic[visualization]

# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 KB 4.6 MB/s eta 0:00:00
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 67.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 63.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 99.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.7 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...

# %% [markdown]
# # 필요한 것들을 임포트

# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %% [markdown]
# # 데이터 불러오기

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/인공지능인문학"
# Out:
# /content/drive/MyDrive/Colab Notebooks/인공지능인문학

# %%
f = open("discrimination.txt")
documents = [line.strip() for line in open("discrimination.txt", encoding="utf-8").readlines()]
documents[:5]
# Out:
# ['text',
#  '남자들은 도대체 왜 그러는걸까?',
#  '말하면서 침 개많이 튀길것 같아.',
#  '머리가 멍청해서 못읽는거아니냐?',
#  '"동유럽, 러시아 애들은 가난해도 사랑으로 결혼하는데 헬조선은 자본주의의 지옥 그 자체다"']

# %% [markdown]
# # Mecab과 SBERT를 이용한 Bertopic (형태소단위)

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=8,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(documents)
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 8):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('ㅋㅋ', 0.0535449431830227), ('남자', 0.04808832895071991), ('짱깨', 0.034379054889425414), ('여자', 0.03262695566753463), ('사람', 0.03164774707548635), ('진짜', 0.0316303592034512), ('그런', 0.029570421643076432), ('전라도', 0.02840008882169925), ('무슨', 0.028097973714044468), ('역시', 0.027842803536166753)]
# 1 번째 토픽 : [('ㅋㅋ', 0.05989280522553489), ('여자', 0.051092926775657854), ('아니', 0.04577549160902824), ('ㅋㅋㅋ', 0.045688900546162696), ('남자', 0.03972132794971543), ('는데', 0.03790974943836207), ('으면', 0.03429429128398896), ('에서', 0.02974352723826818), ('그냥', 0.023245305750340294), ('어서', 0.022988637248549982)]
# 2 번째 토픽 : [('남자', 0.05466629769347726), ('이나', 0.04268927479878742), ('처럼', 0.04240643099598636), ('이랑', 0.04176644823030703), ('이래서', 0.039961012394600245), ('들어가', 0.03614063137374464), ('아니', 0.03585674732607009), ('는데', 0.0355725824808), ('전라도', 0.03514267283829261), ('한테', 0.032805317181035513)]
# ...

# %% [markdown]
# ## 명사단위 분석

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.nouns(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=8,
                 top_n_words=10,
                 calculate_probabilities=True)
topics, probs = model.fit_transform(documents)
for i in range(0, 8):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('여자', 0.0737389321438583), ('남자', 0.06177233972431574), ('주제', 0.03398300772056226), ('우리', 0.03183857518602629), ('사람', 0.029370426066009633), ('얼굴', 0.02561654859603536), ('큰일', 0.024512392436754352), ('하나', 0.02401374583433072), ('장애', 0.02291281586131514), ('차이', 0.022814455105621436)]
# 1 번째 토픽 : [('여자', 0.06343133947858778), ('남자', 0.05147694977026312), ('아이돌', 0.03802409184270239), ('사람', 0.03765439239232004), ('회사', 0.034628768101110145), ('우리', 0.03183857518602629), ('짱깨', 0.02639193367098069), ('결혼', 0.024507272852141507), ('정도', 0.022120519506118475), ('휴가', 0.021367603290090534)]
# 2 번째 토픽 : [('한국', 0.19386716080498978), ('인간', 0.16914463278421304), ('조선족', 0.15078556951499203), ('서울', 0.12983840660944843), ('인물', 0.12035846721141545), ('집단', 0.1060354511687791), ('한국인', 0.07847225082336379), ('북한', 0.06522789173848192), ('남성', 0.06150240313079136), ('사람', 0.05711341652862238)]
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
